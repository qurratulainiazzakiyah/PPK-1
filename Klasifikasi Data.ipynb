# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Downloads/diabetes.csv',header=None)
data
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
data.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#                 6           7           8
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
len(data[data.iloc[:,8]==0])
# Out:
# 500

# %%
x = data.iloc[:,0:8]

# %%
x
# Out:
#       0    1   2   3    4     5      6   7
# 0     6  148  72  35    0  33.6  0.627  50
# 1     1   85  66  29    0  26.6  0.351  31
# 2     8  183  64   0    0  23.3  0.672  32
# 3     1   89  66  23   94  28.1  0.167  21
# 4     0  137  40  35  168  43.1  2.288  33
# ..   ..  ...  ..  ..  ...   ...    ...  ..
# 763  10  101  76  48  180  32.9  0.171  63
# 764   2  122  70  27    0  36.8  0.340  27
# 765   5  121  72  23  112  26.2  0.245  30
# 766   1  126  60   0    0  30.1  0.349  47
# 767   1   93  70  31    0  30.4  0.315  23
#
# [768 rows x 8 columns]

# %%
y=data[8]

# %%
data [8]
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: 8, Length: 768, dtype: int64

# %%
x[0]
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: 0, Length: 768, dtype: int64

# %%
x = x[0]
x = (x - x.min())/(x.max()-x.min())
x
# Out:
# 0      0.352941
# 1      0.058824
# 2      0.470588
# 3      0.058824
# 4      0.000000
#          ...
# 763    0.588235
# 764    0.117647
# 765    0.294118
# 766    0.058824
# 767    0.058824
# Name: 0, Length: 768, dtype: float64

# %%
def normalisasi (data):
    for i in range (len(data.diabetes)):
        data[i] = (data[i] - data[i].min())/(data[i].max()-data[i].min())

# %%
normalisasi(x)
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 normalisasi(x)
#       2 x
#
# Input In [32], in normalisasi(data)
#       1 def normalisasi (data):
# ----> 2     for i in range (len(data.diabetes)):
#       3         data[i] = (data[i] - data[i].min())/(data[i].max()-data[i].min())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'diabetes'
